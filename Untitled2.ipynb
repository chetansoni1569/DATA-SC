# %% [markdown]
# <a href="https://colab.research.google.com/github/chetansoni1569/DATA-SC/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "madam"

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Palindrome

# %%
lst =["chetan", 2, 3, [2,4]]

print(lst)

#append() //single value can be pushed
lst.append(3)
print(lst)

#extend() //multiple value can be pushed
lst.extend(["aman"])
print(lst)

#insert() // push between the index
#lst.insert(index, value)
lst.insert(2, "value")
print(lst)
# Out:
# ['chetan', 2, 3, [2, 4]]
# ['chetan', 2, 3, [2, 4], 3]
# ['chetan', 2, 3, [2, 4], 3, 'aman']
# ['chetan', 2, 'value', 3, [2, 4], 3, 'aman']

# %%
lst =["chetan", 2, 3]
lst.append([23,34])
print(lst)
# Out:
# ['chetan', 2, 3, [23, 34]]

# %%
lst =["chetan", 2, 3]
lst.extend(["aman", 23])
print (lst)
# Out:
# ['chetan', 2, 3, 'aman', 23]

# %%
lst =["chetan", 2, 3]
lst.insert(0,"soni")
print (lst)
# Out:
# ['soni', 'chetan', 2, 3]

# %%
#pop
lst =["chetan", 2, 3]
lst.pop()
print(lst)
# Out:
# ['chetan', 2]

# %%
lst =["chetan", 2, 3,2]
#remove // remove occurance in first move
lst.remove(2)
print(lst)
# Out:
# ['chetan', 3, 2]

# %%
lst =["chetan", 2, 3]
#index
a=lst.index(2)
print(a)
# Out:
# 1

# %%
#count //it counts the number
lst =["chetan", 2,2, 3]
print(lst.count(2))
# Out:
# 2

# %%
#sort()
lst =[1, 2, 3,4,5,6,6]
lst.sort()
print(lst)

#sum #min #max #sorted
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
lst =[1, 2, 3,4,5,6,6]
sum(lst)
# Out:
# 27

# %%
lst =[1, 2, 3,6,5,9,6]
sorted(lst)
# Out:
# [1, 2, 3, 5, 6, 6, 9]

# %%
#tuple

tp= (1,2,33,4)
a=tuple(sorted(tp))
print(sum(tp))
print(min(tp))
print(max(tp))
print(len(tp))
# Out:
# 40
# 1
# 33
# 4

# %%
lst1= []
lst2= []
size= int(input())
for i in range(size):
  x= int(input())

  lst1.append(x)

for j in range(size):
  y=int(input())

  lst2.append(y)

lst3=[]

for i in range(size):
  lst3.append(lst1[i]+lst2[i])

print(lst3)
# Out:
# 2
# 1
# 2
# 3
# 4
# [4, 6]
