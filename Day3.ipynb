# %% [markdown]
# <a href="https://colab.research.google.com/github/chetansoni1569/DATA-SC/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters):
  #body of fun
# Out:
#   File "/tmp/ipykernel_1931/3066265495.py", line 2
#     #body of fun
#                 ^
# SyntaxError: incomplete input

# %%
def sumnum (a,b):
  return a+b

print (sumnum(2,3))
# Out:
# 5

# %%
# lambda function.  //use for one or two line of function
x= lambda a : 2*a
print(x(2))
# Out:
# 4

# %%
x= lambda a,b : b*a
print(x(2,3))
# Out:
# 6

# %%
st= ""
print (len(st))
# Out:
# 0

# %%
st="chetan"
st1= st.upper()
print(st1)
# Out:
# CHETAN

# %%
st="CHETAN"
st1= st.lower()
print(st1)
# Out:
# chetan

# %%
st="chetan verma"
st1= st.title()
print(st1)
# Out:
# Chetan Verma

# %%
st="chetan kumar verma"
st1= st.capitalize()
print(st1)
# Out:
# Chetan kumar verma

# %%
st=' chetan kuamr verma'
#strip
st.strip(' ')
print(st)
# Out:
#  chetan kuamr verma

# %%
first_name=' chetan'
last_name='   verma'

first_name= first_name.strip()
last_name= last_name.strip()

print (first_name+ '  ' +last_name)
# Out:
# chetan  verma

# %%
a= "today "
b= "     weather"
c= "    is gooD"

a=a.strip()
b=b.strip()
c=c.strip()
x= (a+" "+b+" "+c+" ")


print(x.capitalize())
# Out:
# Today weather is good

# %%
x= 'toady weather is good'
x = x.replace("good", "bad")
print(x)
# Out:
# toady weather is bad

# %%
x='toady weather is good'
x=x.find("good")
print(x)
# Out:
# 17

# %%
x='today weather is good'
x=x.startswith('today')
print(x)
# Out:
# True

# %%
x='today weather is good'
x=x.endswith('good')
print(x)
# Out:
# True

# %%
s="hello world"
print(s[-2])
# Out:
# l

# %%
#sets

st={2,2,24,5,61}
print(st)
# Out:
# {24, 2, 5, 61}
